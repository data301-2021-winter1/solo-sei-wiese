# %% [markdown]
# # Seiya Iwama

# %% [markdown]
# ## Research question/interests
# How much does the increase in wealth, especially in national income, tend to reduce inequality?
#
# Will the rate of inequality in the country decrease as the country becomes richer?

# %%
# First, Import the libraries
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
# Load Data from "data" folder.

# pd.read_csv('../data/raw/xxx/yyy.csv')

df_cpi_Algeria = pd.read_csv('../data/raw/00cpi_xxxx/cpi_Algeria.csv')
df_WID_AD = pd.read_csv('../data/raw/00WID_data_00/WID_data_AD.csv', sep = ";")
# df_WID_meta_AD= pd.read_csv('../data/raw/00WID_metadata_00/WID_metadata_AD.csv')

df_AfricanDevelopment = pd.read_csv('../data/raw/AfricanDevelopment.csv')

df_data = pd.read_csv('../data/raw/archive/data.csv')
df_country_variables = pd.read_csv('../data/raw/cpi_variable_data/country_variable.csv')
# df_WID_countries = pd.read_csv('../data/raw/WID_countries.csv')  ERROR
df_WID_countries = pd.read_csv('../data/raw/WID_countries.csv', sep = ";")

# %%
df_cpi_Algeria.head()
# Out:
#     Country Algeria Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0  Variable     CPI    p90p100     p50p90      p0p50    p99p100
# 1      1998       -     0.4193     0.4205     0.1602     0.1149
# 2      1999       -     0.4163     0.4212     0.1625     0.1137
# 3      2000       -     0.4134     0.4218     0.1648     0.1125
# 4      2001       -     0.4104     0.4225     0.1671     0.1113
#
#        Unnamed: 6      Unnamed: 7         Unnamed: 8        Unnamed: 9  \
# 0  Nat Inc pAdult  Nat Inc pAdult  Nat Wealth pAdult  Wealth-Inc Ratio
# 1      12134.2987      13537.6496         56431.7889       4.650601864
# 2      12032.6962       13492.098         56576.5125       4.701898098
# 3      12293.3864      13533.9303         59577.9119       4.846338272
# 4      12157.9037       13462.121         61114.9913       5.026769638
#
#    Unnamed: 10 Unnamed: 11  Unnamed: 12
# 0  10/50 Ratio         Pop          NaN
# 1          NaN         NaN          NaN
# 2          NaN         NaN          NaN
# 3          NaN         NaN          NaN
# 4          NaN         NaN          NaN

# %%
df_WID_AD.head()
# Out:
#   country    variable percentile  year  value  age pop
# 0      AD  mptfrr999i     p0p100  1970    0.0  999   i
# 1      AD  mptfrr999i     p0p100  1971    0.0  999   i
# 2      AD  mptfrr999i     p0p100  1972    0.0  999   i
# 3      AD  mptfrr999i     p0p100  1973    0.0  999   i
# 4      AD  mptfrr999i     p0p100  1974    0.0  999   i

# %%
df_AfricanDevelopment.head()
# Out:
#       country  humanDevelopmentIndex    pop2021
# 0  Seychelles                  0.801     98.908
# 1   Mauritius                  0.796   1273.433
# 2     Algeria                  0.759  44616.624
# 3     Tunisia                  0.739  11935.766
# 4    Botswana                  0.728   2397.241

# %%
df_data.head()
# Out:
#   Jurisdiction 1998 1999 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009  \
# 0  Afghanistan    -    -    -    -    -    -    -  2.5    -  1.8  1.5  1.3
# 1      Albania    -  2.3    -    -  2.5  2.5  2.5  2.4  2.6  2.9  3.4  3.2
# 2      Algeria    -    -    -    -    -  2.6  2.7  2.8  3.1    3  3.2  2.8
# 3       Angola    -    -  1.7    -  1.7  1.8    2    2  2.2  2.2  1.9  1.9
# 4    Argentina    3    3  3.5  3.5  2.8  2.5  2.5  2.8  2.9  2.9  2.9  2.9
#
#   2010  2011 2012 2013 2014 2015
# 0  1.4  1.52    8    8   12   11
# 1  3.3  3.05   33   31   33   36
# 2  2.9   2.9   34   36   36   36
# 3  1.9  2.01   22   23   19   15
# 4  2.9     3   35   34   34   32

# %%
df_country_variables.head()
# Out:
#     Country Mauritius Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0  Variable       CPI    p90p100     p50p90      p0p50    p99p100
# 1      1998         5     0.4578     0.3901      0.152     0.1374
# 2      1999       4.9     0.4578     0.3901      0.152     0.1374
# 3      2000       4.7     0.4578     0.3901      0.152     0.1374
# 4      2001       4.6     0.4578     0.3901      0.152     0.1374
#
#        Unnamed: 6      Unnamed: 7         Unnamed: 8        Unnamed: 9  \
# 0  Nat Inc pAdult  Nat Inc pAdult  Nat Wealth pAdult  Wealth-Inc Ratio
# 1      12783.4058      13855.7675         51900.9383       4.060023785
# 2      13690.6223      14101.1992         57756.4098        4.21868372
# 3      14002.9229      14826.9775         61241.5769       4.373485088
# 4      14514.1506      15197.6426         66289.7585       4.567249775
#
#    Unnamed: 10 Unnamed: 11 Unnamed: 12
# 0  10/50 Ratio         Pop         NaN
# 1          NaN         NaN
# 2          NaN         NaN         NaN
# 3          NaN         NaN         NaN
# 4          NaN         NaN         NaN

# %%
df_WID_countries.head()
# Out:
#   alpha2                 titlename             shortname    region  \
# 0     AM                   Armenia               Armenia      Asia
# 1     AN  the Netherlands Antilles  Netherlands Antilles  Americas
# 2     AO                    Angola                Angola    Africa
# 3     AR                 Argentina             Argentina  Americas
# 4     AS            American Samoa        American Samoa   Oceania
#
#                                      region2
# 0                               Western Asia
# 1                                  Caribbean
# 2                              Middle Africa
# 3                              South America
# 4  Oceania (excl. Australia and New Zealand)

# %%
# print('df_cpi_Algeria - The number of data is {}, the variables are {}.'.format(df_cpi_Algeria.shape[0], df_cpi_Algeria.shape[1]))
# print('df_WID_AD - The number of data is {}, the variables are {}.'.format(df_WID_AD.shape[0], df_WID_AD.shape[1]))
# # print('df_WID_meta_AD - The number of data is {}, the variables are {}.'.format(df_WID_meta_AD.shape[0], df_WID_meta_AD.shape[1]))
# print('df_AfricanDevelopment - The number of data is {}, the variables are {}.'.format(df_AfricanDevelopment.shape[0], df_AfricanDevelopment.shape[1]))
# print('df_data  - The number of data is {}, the variables are {}.'.format(df_data.shape[0], df_data.shape[1]))
# print('df_country_variables  - The number of data is {}, the variables are {}.'.format(df_country_variables.shape[0], df_country_variables.shape[1]))
# print('df_WID_countries  - The number of data is {}, the variables are {}.'.format(df_WID_countries.shape[0], df_WID_countries.shape[1]))

# %%
# print(df_cpi_Algeria.columns)
# print(df_WID_AD.columns)
# print(df_AfricanDevelopment.columns)
# print(df_data.columns)
# print(df_country_variables.columns)
# print(df_WID_countries.columns)

# %% [markdown]
# ### After looking at the data frames as described above, I assume that the following data frames can be used effectively.
# - AfricanDevelopment.csv
# - data.csv
# - country_variable.csv

# %%
print('df_cpi_Algeria - The number of data is {}, the variables are {}.'.format(df_cpi_Algeria.shape[0], df_cpi_Algeria.shape[1]))
print('df_AfricanDevelopment - The number of data is {}, the variables are {}.'.format(df_AfricanDevelopment.shape[0], df_AfricanDevelopment.shape[1]))
print('df_data  - The number of data is {}, the variables are {}.'.format(df_data.shape[0], df_data.shape[1]))
print('df_country_variables  - The number of data is {}, the variables are {}.'.format(df_country_variables.shape[0], df_country_variables.shape[1]))
# print('df_WID_countries  - The number of data is {}, the variables are {}.'.format(df_WID_countries.shape[0], df_WID_countries.shape[1]))
# Out:
# df_cpi_Algeria - The number of data is 24, the variables are 13.
# df_AfricanDevelopment - The number of data is 49, the variables are 3.
# df_data  - The number of data is 227, the variables are 19.
# df_country_variables  - The number of data is 598, the variables are 13.

# %%
print(df_cpi_Algeria.columns)
print(df_AfricanDevelopment.columns)
print(df_data.columns)
print(df_country_variables.columns)
# print(df_WID_countries.columns)
# Out:
# Index(['Country', 'Algeria', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12'],
#       dtype='object')
# Index(['country', 'humanDevelopmentIndex', 'pop2021'], dtype='object')
# Index(['Jurisdiction', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015'],
#       dtype='object')
# Index(['Country', 'Mauritius', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12'],
#       dtype='object')

# %% [markdown]
# ### In the column, I found that I need to change the column names of df_country_variables and df_cpi_Algeria

# %% [markdown]
# ### Check for missing values in the data frames.

# %%
df_AfricanDevelopment.isnull().sum()
# Out:
# country                  0
# humanDevelopmentIndex    1
# pop2021                  0
# dtype: int64

# %% [markdown]
# I found one missing value in humanDevelopmentIndex.
# In this case, since there is only one row of Nan value, I can determine that there is no problem dropping the entire row, so I drop it.

# %%
df_AfricanDevelopment = df_AfricanDevelopment.dropna()
df_AfricanDevelopment.isnull().sum()
# Out:
# country                  0
# humanDevelopmentIndex    0
# pop2021                  0
# dtype: int64

# %%
# df_data.isnull().sum()

# %% [markdown]
# Visualizing the correlation between population of 2021 and HDI in the df_AfricanDevelopment data

# %%
sns.scatterplot(x='humanDevelopmentIndex', y='pop2021', data=df_AfricanDevelopment)
# Out:
# <AxesSubplot:xlabel='humanDevelopmentIndex', ylabel='pop2021'>

# %% [markdown]
# ### The correlation between population of 2021 and HDI was found to be low.

# %%
df_country_variables = pd.read_csv('../data/raw/cpi_variable_data/country_variable.csv', header=1)
df_country_variables.head()
# Out:
#   Variable  CPI p90p100  p50p90  p0p50 p99p100 Nat Inc pAdult  \
# 0     1998    5  0.4578  0.3901  0.152  0.1374     12783.4058
# 1     1999  4.9  0.4578  0.3901  0.152  0.1374     13690.6223
# 2     2000  4.7  0.4578  0.3901  0.152  0.1374     14002.9229
# 3     2001  4.6  0.4578  0.3901  0.152  0.1374     14514.1506
# 4     2002  4.5  0.4578  0.3901  0.152  0.1374     15420.4451
#
#   Nat Inc pAdult.1 Nat Wealth pAdult Wealth-Inc Ratio 10/50 Ratio  Pop  \
# 0       13855.7675        51900.9383      4.060023785         NaN  NaN
# 1       14101.1992        57756.4098       4.21868372         NaN  NaN
# 2       14826.9775        61241.5769      4.373485088         NaN  NaN
# 3       15197.6426        66289.7585      4.567249775         NaN  NaN
# 4       15329.9491        83515.9722       5.41592598         NaN  NaN
#
#   Unnamed: 12
# 0
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
df_country_variables.tail(30)
# Out:
#      Variable     CPI  p90p100  p50p90   p0p50  p99p100  Nat Inc pAdult  \
# 567      2015     2.6   0.4508  0.4052   0.144   0.1286      10411.8236
# 568      2016     2.8   0.4429  0.4094  0.1477   0.1244      10127.2106
# 569      2017     2.7   0.4351  0.4136  0.1513   0.1201        9883.828
# 570      2018     2.7   0.4272  0.4178   0.155   0.1159        9798.785
# 571      2019     2.6   0.4272  0.4178   0.155   0.1159       9844.0407
# 572       NaN     NaN      NaN     NaN     NaN      NaN             NaN
# 573   Country  Uganda      NaN     NaN     NaN      NaN             NaN
# 574  Variable     CPI  p90p100  p50p90   p0p50  p99p100  Nat Inc pAdult
# 575      1998     2.6   0.5177  0.3555  0.1268   0.1803       2082.9199
# 576      1999     2.2   0.5321  0.3462  0.1217   0.1936       2103.9676
# 577      2000     2.3   0.5427  0.3386  0.1188   0.2046       2131.6092
# 578      2001     1.9   0.5533  0.3309  0.1158   0.2156       2201.4728
# 579      2002     2.1   0.5639  0.3232  0.1129   0.2266       2322.5608
# 580      2003     2.2   0.5511  0.3334  0.1155   0.2111       2398.4011
# 581      2004     2.6   0.5383  0.3435  0.1182   0.1956       2428.5392
# 582      2005     2.5   0.5254  0.3537  0.1209   0.1801       2580.1505
# 583      2006     2.7    0.531   0.349    0.12   0.1813       2744.8612
# 584      2007     2.8   0.5366  0.3443  0.1192   0.1825       2889.9024
# 585      2008     2.6   0.5421  0.3395  0.1183   0.1837       3035.6628
# 586      2009     2.5   0.5477  0.3348  0.1175   0.1849       3057.8743
# 587      2010     2.5   0.5332  0.3451  0.1217    0.175       3201.4915
# 588      2011     2.4   0.5188  0.3554  0.1258   0.1651       3262.1802
# 589      2012     2.9   0.5043  0.3657    0.13   0.1553       3255.0008
# 590      2013     2.6   0.5084  0.3638  0.1278   0.1591       3247.6894
# 591      2014     2.6   0.5125  0.3619  0.1256   0.1629       3299.2629
# 592      2015     2.5   0.5166  0.3599  0.1235   0.1667       3334.5277
# 593      2016     2.5   0.5207   0.358  0.1213   0.1705       3299.5522
# 594      2017     2.6   0.5207   0.358  0.1213   0.1705        3285.747
# 595      2018     2.6   0.5207   0.358  0.1213   0.1705       3345.2343
# 596      2019     2.8   0.5207   0.358  0.1213   0.1705       3416.1301
#
#     Nat Inc pAdult.1  Nat Wealth pAdult  Wealth-Inc Ratio  10/50 Ratio  Pop  \
# 567       11245.1641          49138.471       4.719487667          NaN  NaN
# 568       10780.5057         47900.5273       4.729883194          NaN  NaN
# 569        10580.981         46870.9092       4.742182255          NaN  NaN
# 570       10493.4946         46601.4367       4.755838394          NaN  NaN
# 571       10431.1536         46966.5726       4.771066189          NaN  NaN
# 572              NaN                NaN               NaN          NaN  NaN
# 573              NaN                NaN               NaN          NaN  NaN
# 574   Nat Inc pAdult  Nat Wealth pAdult  Wealth-Inc Ratio  10/50 Ratio  Pop
# 575         2233.325          9657.5222       4.636530399          NaN  NaN
# 576         2298.045          9775.8075       4.646368027          NaN  NaN
# 577        2329.5856         10078.4924       4.728114605          NaN  NaN
# 578        2420.7084          10467.473       4.754759312          NaN  NaN
# 579        2532.9686         10937.9487       4.709434986          NaN  NaN
# 580        2623.5007         11430.8525       4.766030312          NaN  NaN
# 581        2702.4082         11719.8001       4.825864315          NaN  NaN
# 582        2845.6448         12735.7424       4.936046124          NaN  NaN
# 583        3019.2957          14346.222       5.226574898          NaN  NaN
# 584        3169.7805         15308.1384       5.297112465          NaN  NaN
# 585        3327.9798         16071.9061       5.294364929          NaN  NaN
# 586        3383.4353         16332.4302       5.341105938          NaN  NaN
# 587        3517.6791         16986.9598       5.305951595          NaN  NaN
# 588        3607.9746          17369.214       5.324419022          NaN  NaN
# 589        3606.8477         17336.4687       5.326102734          NaN  NaN
# 590        3625.4111         17303.0997       5.327818394          NaN  NaN
# 591        3664.8173         17547.1459        5.31850481          NaN  NaN
# 592        3692.4381         17544.8723       5.261576176          NaN  NaN
# 593        3686.7841         17424.9607       5.281007767          NaN  NaN
# 594        3702.0586         17496.0173       5.324821949          NaN  NaN
# 595        3766.5276         17867.5851       5.341205597          NaN  NaN
# 596        3842.8652         18338.3356       5.368160725          NaN  NaN
#
#     Unnamed: 12
# 567         NaN
# 568         NaN
# 569         NaN
# 570         NaN
# 571         NaN
# 572         NaN
# 573         NaN
# 574         NaN
# 575         NaN
# 576         NaN
# 577         NaN
# 578         NaN
# 579         NaN
# 580         NaN
# 581         NaN
# 582         NaN
# 583         NaN
# 584         NaN
# 585         NaN
# 586         NaN
# 587         NaN
# 588         NaN
# 589         NaN
# 590         NaN
# 591         NaN
# 592         NaN
# 593         NaN
# 594         NaN
# 595         NaN
# 596         NaN

# %% [markdown]
# I could see the country names forming a line, as in line 573.
# So I decided to check the missing values to exclude these lines.

# %%
df_country_variables.isnull().sum()
# Out:
# Variable              23
# CPI                   23
# p90p100               68
# p50p90                68
# p0p50                 68
# p99p100               68
# Nat Inc pAdult        68
# Nat Inc pAdult.1      68
# Nat Wealth pAdult     68
# Wealth-Inc Ratio      68
# 10/50 Ratio          574
# Pop                  558
# Unnamed: 12          596
# dtype: int64

# %% [markdown]
# From the above, the lines to be excluded were visualized.

# %%
missing_columns = ['10/50 Ratio', 'Pop', 'Unnamed: 12']
df_country_variables.drop(missing_columns, axis=1, inplace=True)

# %%
df_country_variables.tail(30)
# Out:
#      Variable     CPI  p90p100  p50p90   p0p50  p99p100  Nat Inc pAdult  \
# 567      2015     2.6   0.4508  0.4052   0.144   0.1286      10411.8236
# 568      2016     2.8   0.4429  0.4094  0.1477   0.1244      10127.2106
# 569      2017     2.7   0.4351  0.4136  0.1513   0.1201        9883.828
# 570      2018     2.7   0.4272  0.4178   0.155   0.1159        9798.785
# 571      2019     2.6   0.4272  0.4178   0.155   0.1159       9844.0407
# 572       NaN     NaN      NaN     NaN     NaN      NaN             NaN
# 573   Country  Uganda      NaN     NaN     NaN      NaN             NaN
# 574  Variable     CPI  p90p100  p50p90   p0p50  p99p100  Nat Inc pAdult
# 575      1998     2.6   0.5177  0.3555  0.1268   0.1803       2082.9199
# 576      1999     2.2   0.5321  0.3462  0.1217   0.1936       2103.9676
# 577      2000     2.3   0.5427  0.3386  0.1188   0.2046       2131.6092
# 578      2001     1.9   0.5533  0.3309  0.1158   0.2156       2201.4728
# 579      2002     2.1   0.5639  0.3232  0.1129   0.2266       2322.5608
# 580      2003     2.2   0.5511  0.3334  0.1155   0.2111       2398.4011
# 581      2004     2.6   0.5383  0.3435  0.1182   0.1956       2428.5392
# 582      2005     2.5   0.5254  0.3537  0.1209   0.1801       2580.1505
# 583      2006     2.7    0.531   0.349    0.12   0.1813       2744.8612
# 584      2007     2.8   0.5366  0.3443  0.1192   0.1825       2889.9024
# 585      2008     2.6   0.5421  0.3395  0.1183   0.1837       3035.6628
# 586      2009     2.5   0.5477  0.3348  0.1175   0.1849       3057.8743
# 587      2010     2.5   0.5332  0.3451  0.1217    0.175       3201.4915
# 588      2011     2.4   0.5188  0.3554  0.1258   0.1651       3262.1802
# 589      2012     2.9   0.5043  0.3657    0.13   0.1553       3255.0008
# 590      2013     2.6   0.5084  0.3638  0.1278   0.1591       3247.6894
# 591      2014     2.6   0.5125  0.3619  0.1256   0.1629       3299.2629
# 592      2015     2.5   0.5166  0.3599  0.1235   0.1667       3334.5277
# 593      2016     2.5   0.5207   0.358  0.1213   0.1705       3299.5522
# 594      2017     2.6   0.5207   0.358  0.1213   0.1705        3285.747
# 595      2018     2.6   0.5207   0.358  0.1213   0.1705       3345.2343
# 596      2019     2.8   0.5207   0.358  0.1213   0.1705       3416.1301
#
#     Nat Inc pAdult.1  Nat Wealth pAdult  Wealth-Inc Ratio
# 567       11245.1641          49138.471       4.719487667
# 568       10780.5057         47900.5273       4.729883194
# 569        10580.981         46870.9092       4.742182255
# 570       10493.4946         46601.4367       4.755838394
# 571       10431.1536         46966.5726       4.771066189
# 572              NaN                NaN               NaN
# 573              NaN                NaN               NaN
# 574   Nat Inc pAdult  Nat Wealth pAdult  Wealth-Inc Ratio
# 575         2233.325          9657.5222       4.636530399
# 576         2298.045          9775.8075       4.646368027
# 577        2329.5856         10078.4924       4.728114605
# 578        2420.7084          10467.473       4.754759312
# 579        2532.9686         10937.9487       4.709434986
# 580        2623.5007         11430.8525       4.766030312
# 581        2702.4082         11719.8001       4.825864315
# 582        2845.6448         12735.7424       4.936046124
# 583        3019.2957          14346.222       5.226574898
# 584        3169.7805         15308.1384       5.297112465
# 585        3327.9798         16071.9061       5.294364929
# 586        3383.4353         16332.4302       5.341105938
# 587        3517.6791         16986.9598       5.305951595
# 588        3607.9746          17369.214       5.324419022
# 589        3606.8477         17336.4687       5.326102734
# 590        3625.4111         17303.0997       5.327818394
# 591        3664.8173         17547.1459        5.31850481
# 592        3692.4381         17544.8723       5.261576176
# 593        3686.7841         17424.9607       5.281007767
# 594        3702.0586         17496.0173       5.324821949
# 595        3766.5276         17867.5851       5.341205597
# 596        3842.8652         18338.3356       5.368160725

# %%
df_country_variables.isnull().sum()
# Out:
# Variable             23
# CPI                  23
# p90p100              68
# p50p90               68
# p0p50                68
# p99p100              68
# Nat Inc pAdult       68
# Nat Inc pAdult.1     68
# Nat Wealth pAdult    68
# Wealth-Inc Ratio     68
# dtype: int64

# %%
# df_country_variables = df_country_variables.dropna()
df_country_variables = df_country_variables[df_country_variables['Variable'].astype(str).str.isdecimal()]
df_country_variables.tail(30)
# Out:
#     Variable  CPI p90p100  p50p90   p0p50 p99p100 Nat Inc pAdult  \
# 564     2012  2.7  0.4742  0.3926  0.1332  0.1413      9384.7331
# 565     2013  2.5  0.4664  0.3968  0.1368  0.1371      9803.7324
# 566     2014  2.7  0.4586   0.401  0.1404  0.1328      10331.504
# 567     2015  2.6  0.4508  0.4052   0.144  0.1286     10411.8236
# 568     2016  2.8  0.4429  0.4094  0.1477  0.1244     10127.2106
# 569     2017  2.7  0.4351  0.4136  0.1513  0.1201       9883.828
# 570     2018  2.7  0.4272  0.4178   0.155  0.1159       9798.785
# 571     2019  2.6  0.4272  0.4178   0.155  0.1159      9844.0407
# 575     1998  2.6  0.5177  0.3555  0.1268  0.1803      2082.9199
# 576     1999  2.2  0.5321  0.3462  0.1217  0.1936      2103.9676
# 577     2000  2.3  0.5427  0.3386  0.1188  0.2046      2131.6092
# 578     2001  1.9  0.5533  0.3309  0.1158  0.2156      2201.4728
# 579     2002  2.1  0.5639  0.3232  0.1129  0.2266      2322.5608
# 580     2003  2.2  0.5511  0.3334  0.1155  0.2111      2398.4011
# 581     2004  2.6  0.5383  0.3435  0.1182  0.1956      2428.5392
# 582     2005  2.5  0.5254  0.3537  0.1209  0.1801      2580.1505
# 583     2006  2.7   0.531   0.349    0.12  0.1813      2744.8612
# 584     2007  2.8  0.5366  0.3443  0.1192  0.1825      2889.9024
# 585     2008  2.6  0.5421  0.3395  0.1183  0.1837      3035.6628
# 586     2009  2.5  0.5477  0.3348  0.1175  0.1849      3057.8743
# 587     2010  2.5  0.5332  0.3451  0.1217   0.175      3201.4915
# 588     2011  2.4  0.5188  0.3554  0.1258  0.1651      3262.1802
# 589     2012  2.9  0.5043  0.3657    0.13  0.1553      3255.0008
# 590     2013  2.6  0.5084  0.3638  0.1278  0.1591      3247.6894
# 591     2014  2.6  0.5125  0.3619  0.1256  0.1629      3299.2629
# 592     2015  2.5  0.5166  0.3599  0.1235  0.1667      3334.5277
# 593     2016  2.5  0.5207   0.358  0.1213  0.1705      3299.5522
# 594     2017  2.6  0.5207   0.358  0.1213  0.1705       3285.747
# 595     2018  2.6  0.5207   0.358  0.1213  0.1705      3345.2343
# 596     2019  2.8  0.5207   0.358  0.1213  0.1705      3416.1301
#
#     Nat Inc pAdult.1 Nat Wealth pAdult Wealth-Inc Ratio
# 564       10452.0163        44278.3003      4.718120575
# 565       10865.1827        46276.6814      4.720312595
# 566       11251.7267        48741.7752      4.717781067
# 567       11245.1641         49138.471      4.719487667
# 568       10780.5057        47900.5273      4.729883194
# 569        10580.981        46870.9092      4.742182255
# 570       10493.4946        46601.4367      4.755838394
# 571       10431.1536        46966.5726      4.771066189
# 575         2233.325         9657.5222      4.636530399
# 576         2298.045         9775.8075      4.646368027
# 577        2329.5856        10078.4924      4.728114605
# 578        2420.7084         10467.473      4.754759312
# 579        2532.9686        10937.9487      4.709434986
# 580        2623.5007        11430.8525      4.766030312
# 581        2702.4082        11719.8001      4.825864315
# 582        2845.6448        12735.7424      4.936046124
# 583        3019.2957         14346.222      5.226574898
# 584        3169.7805        15308.1384      5.297112465
# 585        3327.9798        16071.9061      5.294364929
# 586        3383.4353        16332.4302      5.341105938
# 587        3517.6791        16986.9598      5.305951595
# 588        3607.9746         17369.214      5.324419022
# 589        3606.8477        17336.4687      5.326102734
# 590        3625.4111        17303.0997      5.327818394
# 591        3664.8173        17547.1459       5.31850481
# 592        3692.4381        17544.8723      5.261576176
# 593        3686.7841        17424.9607      5.281007767
# 594        3702.0586        17496.0173      5.324821949
# 595        3766.5276        17867.5851      5.341205597
# 596        3842.8652        18338.3356      5.368160725

# %%
df_data.head()
# Out:
#   Jurisdiction 1998 1999 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009  \
# 0  Afghanistan  NaN  NaN  NaN  NaN  NaN  NaN  NaN  2.5  NaN  1.8  1.5  1.3
# 1      Albania  NaN  2.3  NaN  NaN  2.5  2.5  2.5  2.4  2.6  2.9  3.4  3.2
# 2      Algeria  NaN  NaN  NaN  NaN  NaN  2.6  2.7  2.8  3.1    3  3.2  2.8
# 3       Angola  NaN  NaN  1.7  NaN  1.7  1.8    2    2  2.2  2.2  1.9  1.9
# 4    Argentina    3    3  3.5  3.5  2.8  2.5  2.5  2.8  2.9  2.9  2.9  2.9
#
#   2010  2011 2012 2013 2014 2015
# 0  1.4  1.52    8    8   12   11
# 1  3.3  3.05   33   31   33   36
# 2  2.9   2.9   34   36   36   36
# 3  1.9  2.01   22   23   19   15
# 4  2.9     3   35   34   34   32

# %%
df_data.isnull().sum()
# Out:
# Jurisdiction    0
# 1998            0
# 1999            0
# 2000            0
# 2001            0
# 2002            0
# 2003            0
# 2004            0
# 2005            0
# 2006            0
# 2007            0
# 2008            0
# 2009            0
# 2010            0
# 2011            0
# 2012            0
# 2013            0
# 2014            0
# 2015            0
# dtype: int64

# %%
# Turn "-" in the table into Nan
df_data = df_data.replace(['-'], np.nan)

# %%
df_data.tail()
# Out:
#     Jurisdiction 1998 1999 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009  \
# 222     Viet Nam  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  2.6  2.6  2.7  NaN
# 223        Yemen  NaN  NaN  NaN  NaN  NaN  2.6  2.4  2.7  2.6  2.5  2.3  2.1
# 224   Yugoslavia    3    2  1.3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 225       Zambia  3.5  3.5  3.4  2.6  2.6  2.5  2.6  2.6  2.6  2.6  2.8    3
# 226     Zimbabwe  4.2  4.1    3  2.9  2.7  2.3  2.3  2.6  2.4  2.1  1.8  2.2
#
#     2010  2011 2012 2013 2014 2015
# 222  NaN   NaN  NaN  NaN  NaN  NaN
# 223  2.2  2.08   23   18   19   18
# 224  NaN   NaN  NaN  NaN  NaN  NaN
# 225    3   3.2   37   38   38   38
# 226  2.4  2.23   20   21   21   21

# %%
df_data.count()
# Out:
# Jurisdiction    227
# 1998             85
# 1999             99
# 2000             90
# 2001             91
# 2002            102
# 2003            133
# 2004            146
# 2005            159
# 2006            163
# 2007            180
# 2008            180
# 2009            180
# 2010            178
# 2011            183
# 2012            176
# 2013            177
# 2014            175
# 2015            168
# dtype: int64

# %%
df_data.mean(numeric_only=True)
# Out:
# Series([], dtype: float64)

# %%
mean_df_data = df_data.mean()
mean_df_data
# Out:
# /var/folders/6r/wy6cqjq50_q5b67c52fmh8g00000gn/T/ipykernel_18218/1835862742.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   mean_df_data = df_data.mean()
# Series([], dtype: float64)

# %%
df_data.describe()
# Out:
#        Jurisdiction 1998 1999 2000 2001 2002 2003 2004 2005 2006 2007 2008  \
# count           227   85   99   90   91  102  133  146  159  163  180  180
# unique          227   57   57   56   57   50   55   64   60   58   64   61
# top     Afghanistan    3  2.6  3.5  2.9  2.7  2.5  2.3  2.6  2.6  2.1  3.6
# freq              1    5    5    5    4    6    8    8   10   10   12    8
#
#        2009 2010  2011 2012 2013 2014 2015
# count   180  178   183  176  177  175  168
# unique   66   67   155   69   68   68   64
# top     2.8  2.1  2.69   34   28   38   36
# freq      9   10     3    8    9    9    7

# %%
print(df_data.dtypes)
# Out:
# Jurisdiction    object
# 1998            object
# 1999            object
# 2000            object
# 2001            object
# 2002            object
# 2003            object
# 2004            object
# 2005            object
# 2006            object
# 2007            object
# 2008            object
# 2009            object
# 2010            object
# 2011            object
# 2012            object
# 2013            object
# 2014            object
# 2015            object
# dtype: object

# %%
i_year = 1998
while i_year < 2016:
    df_data[f.'{i_year}'].astype(object).astype(float)
    i_year+=1
# Out:
#   File "/var/folders/6r/wy6cqjq50_q5b67c52fmh8g00000gn/T/ipykernel_18218/2766378320.py", line 3
#     df_data[f.'{i_year}'].astype(object).astype(float)
#               ^
# SyntaxError: invalid syntax

# %%
# df_data['1998'].astype(object).astype(float)
# df_data['1999'].astype(object).astype(float)
# df_data['2000'].astype(object).astype(float)
# df_data['2001'].astype(object).astype(float)
# df_data['2002'].astype(object).astype(float)
# df_data['2003'].astype(object).astype(float)
# df_data['2004'].astype(object).astype(float)
# df_data['2005'].astype(object).astype(float)
# df_data['2006'].astype(object).astype(float)
# df_data['2007'].astype(object).astype(float)
# df_data['2008'].astype(object).astype(float)
# df_data['2009'].astype(object).astype(float)
# df_data['2010'].astype(object).astype(float)
# df_data['2011'].astype(object).astype(float)
# df_data['2012'].astype(object).astype(float)
# df_data['2013'].astype(object).astype(float)
# df_data['2014'].astype(object).astype(float)
# df_data['2015'].astype(object).astype(float)



df_data_f = df_data.astype({'1998': 'float64', '1999': 'float64', 
                            '2000': 'float64', '2001': 'float64', 
                            '2002': 'float64', '2003': 'float64', 
                            '2004': 'float64', '2005': 'float64', 
                            '2006': 'float64', '2007': 'float64', 
                            '2008': 'float64', '2009': 'float64', 
                            '2010': 'float64', '2011': 'float64', 
                            '2012': 'float64', '2013': 'float64', 
                            '2014': 'float64', '2015': 'float64', })

# %%
print(df_data_f.dtypes)
# Out:
# Jurisdiction     object
# 1998            float64
# 1999            float64
# 2000            float64
# 2001            float64
# 2002            float64
# 2003            float64
# 2004            float64
# 2005            float64
# 2006            float64
# 2007            float64
# 2008            float64
# 2009            float64
# 2010            float64
# 2011            float64
# 2012            float64
# 2013            float64
# 2014            float64
# 2015            float64
# dtype: object

# %%
df_data_f.head(15)
# Out:
#    Jurisdiction  1998  1999  2000  2001  2002  2003  2004  2005  2006  2007  \
# 0   Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   2.5   NaN   1.8
# 1       Albania   NaN   2.3   NaN   NaN   2.5   2.5   2.5   2.4   2.6   2.9
# 2       Algeria   NaN   NaN   NaN   NaN   NaN   2.6   2.7   2.8   3.1   3.0
# 3        Angola   NaN   NaN   1.7   NaN   1.7   1.8   2.0   2.0   2.2   2.2
# 4     Argentina   3.0   3.0   3.5   3.5   2.8   2.5   2.5   2.8   2.9   2.9
# 5       Armenia   NaN   2.5   2.5   NaN   NaN   3.0   3.1   2.9   2.9   3.0
# 6     Australia   8.7   8.7   8.3   8.5   8.6   8.8   8.8   8.8   8.7   8.6
# 7       Austria   7.5   7.6   7.7   7.8   7.8   8.0   8.4   8.7   8.6   8.1
# 8    Azerbaijan   NaN   1.7   1.5   2.0   2.0   1.8   1.9   2.2   2.4   2.1
# 9       Bahamas   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 10      Bahrain   NaN   NaN   NaN   NaN   NaN   6.1   5.8   5.8   5.7   5.0
# 11   Bangladesh   NaN   NaN   NaN   0.4   1.2   1.3   1.5   1.7   2.0   2.0
# 12     Barbados   NaN   NaN   NaN   NaN   NaN   NaN   7.3   6.9   6.7   6.9
# 13      Belarus   3.9   3.4   4.1   NaN   4.8   4.2   3.3   2.6   2.1   2.1
# 14      Belgium   5.4   5.3   6.1   6.6   7.1   7.6   7.5   7.4   7.3   7.1
#
#     2008  2009  2010  2011  2012  2013  2014  2015
# 0    1.5   1.3   1.4  1.52   8.0   8.0  12.0  11.0
# 1    3.4   3.2   3.3  3.05  33.0  31.0  33.0  36.0
# 2    3.2   2.8   2.9  2.90  34.0  36.0  36.0  36.0
# 3    1.9   1.9   1.9  2.01  22.0  23.0  19.0  15.0
# 4    2.9   2.9   2.9  3.00  35.0  34.0  34.0  32.0
# 5    2.9   2.7   2.6  2.63  34.0  36.0  37.0  35.0
# 6    8.7   8.7   8.7  8.84  85.0  81.0  80.0  79.0
# 7    8.1   7.9   7.9  7.79  69.0  69.0  72.0  76.0
# 8    1.9   2.3   2.4  2.38  27.0  28.0  29.0  29.0
# 9    NaN   NaN   NaN  7.29  71.0  71.0  71.0   NaN
# 10   5.4   5.1   4.9  5.11  51.0  48.0  49.0  51.0
# 11   2.1   2.4   2.4  2.66  26.0  27.0  25.0  25.0
# 12   7.0   7.4   7.8  7.77  76.0  75.0  74.0   NaN
# 13   2.0   2.4   2.5  2.42  31.0  29.0  31.0  32.0
# 14   7.3   7.1   7.1  7.49  75.0  75.0  76.0  77.0

# %%
# Align the digits of the data by dividing the data from 2012 to 2015 by 10.
# df_data_f = df_data_f[{'2012','2013', '2014', '2015'}].apply(lambda x : x /10)
# df_data_f[{'2012','2013', '2014', '2015'}] =  df_data_f.apply(lambda x : x /10)
df_data_f['2012'] =  df_data_f.apply(lambda x : (x['2012'] /10), axis=1)
df_data_f['2013'] =  df_data_f.apply(lambda x : (x['2013'] /10), axis=1)
df_data_f['2014'] =  df_data_f.apply(lambda x : (x['2014'] /10), axis=1)
df_data_f['2015'] =  df_data_f.apply(lambda x : (x['2015'] /10), axis=1)

# df_data_f = df['e']  = df.apply(lambda x: x.a+x.b, axis = 1)

# %%
df_data_f.head()
# Out:
#   Jurisdiction  1998  1999  2000  2001  2002  2003  2004  2005  2006  2007  \
# 0  Afghanistan   NaN   NaN   NaN   NaN   NaN   NaN   NaN   2.5   NaN   1.8
# 1      Albania   NaN   2.3   NaN   NaN   2.5   2.5   2.5   2.4   2.6   2.9
# 2      Algeria   NaN   NaN   NaN   NaN   NaN   2.6   2.7   2.8   3.1   3.0
# 3       Angola   NaN   NaN   1.7   NaN   1.7   1.8   2.0   2.0   2.2   2.2
# 4    Argentina   3.0   3.0   3.5   3.5   2.8   2.5   2.5   2.8   2.9   2.9
#
#    2008  2009  2010  2011  2012  2013  2014  2015
# 0   1.5   1.3   1.4  1.52   0.8   0.8   1.2   1.1
# 1   3.4   3.2   3.3  3.05   3.3   3.1   3.3   3.6
# 2   3.2   2.8   2.9  2.90   3.4   3.6   3.6   3.6
# 3   1.9   1.9   1.9  2.01   2.2   2.3   1.9   1.5
# 4   2.9   2.9   2.9  3.00   3.5   3.4   3.4   3.2

# %%
df_data_f.mean()
# Out:
# /var/folders/6r/wy6cqjq50_q5b67c52fmh8g00000gn/T/ipykernel_18218/2867754704.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_data_f.mean()
# 1998    4.887059
# 1999    4.604040
# 2000    4.758889
# 2001    4.761538
# 2002    4.557843
# 2003    4.223308
# 2004    4.163699
# 2005    4.077987
# 2006    4.091411
# 2007    3.993333
# 2008    4.022222
# 2009    4.031111
# 2010    4.007865
# 2011    4.029344
# 2012    4.326705
# 2013    4.265537
# 2014    4.318857
# 2015    4.257143
# dtype: float64

# %%
df_data_f_float_only = df_data_f[df_data_f.columns[df_data_f.columns != 'Jurisdiction']]
df_data_f_float_only
# Out:
#      1998  1999  2000  2001  2002  2003  2004  2005  2006  2007  2008  2009  \
# 0     NaN   NaN   NaN   NaN   NaN   NaN   NaN   2.5   NaN   1.8   1.5   1.3
# 1     NaN   2.3   NaN   NaN   2.5   2.5   2.5   2.4   2.6   2.9   3.4   3.2
# 2     NaN   NaN   NaN   NaN   NaN   2.6   2.7   2.8   3.1   3.0   3.2   2.8
# 3     NaN   NaN   1.7   NaN   1.7   1.8   2.0   2.0   2.2   2.2   1.9   1.9
# 4     3.0   3.0   3.5   3.5   2.8   2.5   2.5   2.8   2.9   2.9   2.9   2.9
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 222   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   2.6   2.6   2.7   NaN
# 223   NaN   NaN   NaN   NaN   NaN   2.6   2.4   2.7   2.6   2.5   2.3   2.1
# 224   3.0   2.0   1.3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 225   3.5   3.5   3.4   2.6   2.6   2.5   2.6   2.6   2.6   2.6   2.8   3.0
# 226   4.2   4.1   3.0   2.9   2.7   2.3   2.3   2.6   2.4   2.1   1.8   2.2
#
#      2010  2011  2012  2013  2014  2015
# 0     1.4  1.52   0.8   0.8   1.2   1.1
# 1     3.3  3.05   3.3   3.1   3.3   3.6
# 2     2.9  2.90   3.4   3.6   3.6   3.6
# 3     1.9  2.01   2.2   2.3   1.9   1.5
# 4     2.9  3.00   3.5   3.4   3.4   3.2
# ..    ...   ...   ...   ...   ...   ...
# 222   NaN   NaN   NaN   NaN   NaN   NaN
# 223   2.2  2.08   2.3   1.8   1.9   1.8
# 224   NaN   NaN   NaN   NaN   NaN   NaN
# 225   3.0  3.20   3.7   3.8   3.8   3.8
# 226   2.4  2.23   2.0   2.1   2.1   2.1
#
# [227 rows x 18 columns]

# %%
ax_data = df_data_f_float_only.mean().plot(figsize=(13, 6), title='Yearly average of global CPI')
ax_data.set_xlabel("Year")
ax_data.set_ylabel("CPI value")
# Out:
# Text(0, 0.5, 'CPI value')

# %% [markdown]
# The above graph shows that the average global CPI has not grown significantly from year to year.
# In other words, the CPI values do not vary much from year to year.

# %% [markdown]
# ## Then, depending on the HDI value, decide which countries to explore in depth.

# %%
df_AfricanDevelopment_SORTED_by_HDI = df_AfricanDevelopment.sort_values('humanDevelopmentIndex', ascending=False)
df_AfricanDevelopment_SORTED_by_HDI.head()
# Out:
#       country  humanDevelopmentIndex    pop2021
# 0  Seychelles                  0.801     98.908
# 1   Mauritius                  0.796   1273.433
# 2     Algeria                  0.759  44616.624
# 3     Tunisia                  0.739  11935.766
# 4    Botswana                  0.728   2397.241

# %%
df_AfricanDevelopment_SORTED_by_HDI.tail()
# Out:
#         country  humanDevelopmentIndex    pop2021
# 43         Mali                  0.427  20855.735
# 44      Burundi                  0.423  12255.433
# 45  South Sudan                  0.413  11381.378
# 46         Chad                  0.401  16914.985
# 47        Niger                  0.377  25130.817

# %%
df_AfricanDevelopment_SORTED_by_HDI.describe()
# Out:
#        humanDevelopmentIndex        pop2021
# count              48.000000      48.000000
# mean                0.558271   25506.307125
# std                 0.109167   37199.264355
# min                 0.377000      98.908000
# 25%                 0.469000    3347.936250
# 50%                 0.531000   13386.878500
# 75%                 0.608250   29253.528250
# max                 0.801000  211400.708000

# %% [markdown]
# ## Based on the above humanDevelopmentIndex data, I decided to take a deeper look at the four countries of
# ### - Guinea,
# ### - Nigeria,
# ### - Congo, and
# ### - Mauritius.
#
# ### These four countries have HDI values of about 25%, 50%, 75%, and almost maximum, respectively in this data frame.

# %%
df_cpi_guinea= pd.read_csv('../data/raw/00cpi_xxxx/cpi_guinea.csv',header=1)
df_cpi_guinea
# Out:
#     Variable  CPI  p90p100  p50p90   p0p50  p99p100  Nat Inc pAdult  \
# 0     1998.0    -   0.5116  0.3690  0.1187   0.1647      11624.5063
# 1     1999.0    -   0.5136  0.3678  0.1179   0.1668      13773.5394
# 2     2000.0    -   0.5156  0.3665  0.1190   0.1689      15300.3521
# 3     2001.0    -   0.5124  0.3686  0.1198   0.1672      24271.8596
# 4     2002.0    -   0.5096  0.3706  0.1207   0.1643      27524.9361
# 5     2003.0    -   0.5065  0.3728  0.1208   0.1606      29655.2327
# 6     2004.0    -   0.5055  0.3737  0.1147   0.1595      39183.8124
# 7     2005.0  1.9   0.5206  0.3647  0.1151   0.1799      43431.3384
# 8     2006.0  2.1   0.5191  0.3658  0.1155   0.1781      44596.8982
# 9     2007.0  1.9   0.5176  0.3670  0.1157   0.1763      48575.5827
# 10    2008.0  1.7   0.5168  0.3676  0.1163   0.1753      54457.8246
# 11    2009.0  1.8   0.5144  0.3693  0.1169   0.1728      49919.5490
# 12    2010.0  1.9   0.5121  0.3710  0.1175   0.1703      42744.1209
# 13    2011.0  1.9   0.5098  0.3728  0.1182   0.1678      43874.0274
# 14    2012.0    2   0.5072  0.3746  0.1174   0.1650      45122.3024
# 15    2013.0  1.9   0.5089  0.3737  0.1166   0.1668      40522.3497
# 16    2014.0    -   0.5106  0.3727  0.1161   0.1686      38367.7465
# 17    2015.0    -   0.5120  0.3719  0.1156   0.1703      31363.1582
# 18    2016.0    -   0.5134  0.3710  0.1150   0.1722      26772.7323
# 19    2017.0  1.7   0.5149  0.3701  0.1145   0.1740      24743.0508
# 20    2018.0  1.6   0.5164  0.3691  0.1145   0.1759      22541.6219
# 21    2019.0  1.6   0.5164  0.3692  0.1145   0.1759      19862.8626
# 22       NaN  NaN      NaN     NaN     NaN      NaN             NaN
#
#     Nat Inc pAdult.1  Nat Wealth pAdult  Wealth-Inc Ratio  10/50 Ratio  Pop  \
# 0         14144.7280         10356.1138          0.890886          NaN  NaN
# 1         16917.9534         18031.7409          1.309158          NaN  NaN
# 2         19003.0928         26445.7982          1.728444          NaN  NaN
# 3         29693.3463         40917.3153          1.685792          NaN  NaN
# 4         33781.7149         45517.7047          1.653690          NaN  NaN
# 5         36536.1670         52778.4288          1.779734          NaN  NaN
# 6         47758.5816         78389.0930          2.000548          NaN  NaN
# 7         52796.3483         91283.0043          2.101777          NaN  NaN
# 8         54191.4141         96386.6649          2.161286          NaN  NaN
# 9         59348.9636        106050.3398          2.183203          NaN  NaN
# 10        66240.4755        117965.7398          2.166185          NaN  NaN
# 11        63507.3710        107691.5633          2.157302          NaN  NaN
# 12        54733.4669         87639.7818          2.050335          NaN  NaN
# 13        55849.9640         89138.2227          2.031685          NaN  NaN
# 14        57803.0436         93359.3469          2.069029          NaN  NaN
# 15        52830.0008         85430.0938          2.108222          NaN  NaN
# 16        50508.8658         80745.5391          2.104516          NaN  NaN
# 17        43721.5862         64587.8987          2.059356          NaN  NaN
# 18        38539.1077         53606.8191          2.002292          NaN  NaN
# 19        35045.0157         49425.7800          1.997562          NaN  NaN
# 20        31545.1525         45095.0435          2.000524          NaN  NaN
# 21        28578.5177         40194.3598          2.023593          NaN  NaN
# 22               NaN                NaN               NaN          NaN  NaN
#
#     Unnamed: 12
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN

# %%
df_cpi_guinea.isnull().sum()
# Out:
# Variable              1
# CPI                   1
# p90p100               1
# p50p90                1
# p0p50                 1
# p99p100               1
# Nat Inc pAdult        1
# Nat Inc pAdult.1      1
# Nat Wealth pAdult     1
# Wealth-Inc Ratio      1
# 10/50 Ratio          23
# Pop                  23
# Unnamed: 12          23
# dtype: int64

# %%
missing_columns_guinea = ['CPI', '10/50 Ratio', 'Pop', 'Unnamed: 12']
df_cpi_guinea.drop(missing_columns_guinea, axis=1, inplace=True)
df_cpi_guinea
# Out:
#     Variable  p90p100  p50p90   p0p50  p99p100  Nat Inc pAdult  \
# 0     1998.0   0.5116  0.3690  0.1187   0.1647      11624.5063
# 1     1999.0   0.5136  0.3678  0.1179   0.1668      13773.5394
# 2     2000.0   0.5156  0.3665  0.1190   0.1689      15300.3521
# 3     2001.0   0.5124  0.3686  0.1198   0.1672      24271.8596
# 4     2002.0   0.5096  0.3706  0.1207   0.1643      27524.9361
# 5     2003.0   0.5065  0.3728  0.1208   0.1606      29655.2327
# 6     2004.0   0.5055  0.3737  0.1147   0.1595      39183.8124
# 7     2005.0   0.5206  0.3647  0.1151   0.1799      43431.3384
# 8     2006.0   0.5191  0.3658  0.1155   0.1781      44596.8982
# 9     2007.0   0.5176  0.3670  0.1157   0.1763      48575.5827
# 10    2008.0   0.5168  0.3676  0.1163   0.1753      54457.8246
# 11    2009.0   0.5144  0.3693  0.1169   0.1728      49919.5490
# 12    2010.0   0.5121  0.3710  0.1175   0.1703      42744.1209
# 13    2011.0   0.5098  0.3728  0.1182   0.1678      43874.0274
# 14    2012.0   0.5072  0.3746  0.1174   0.1650      45122.3024
# 15    2013.0   0.5089  0.3737  0.1166   0.1668      40522.3497
# 16    2014.0   0.5106  0.3727  0.1161   0.1686      38367.7465
# 17    2015.0   0.5120  0.3719  0.1156   0.1703      31363.1582
# 18    2016.0   0.5134  0.3710  0.1150   0.1722      26772.7323
# 19    2017.0   0.5149  0.3701  0.1145   0.1740      24743.0508
# 20    2018.0   0.5164  0.3691  0.1145   0.1759      22541.6219
# 21    2019.0   0.5164  0.3692  0.1145   0.1759      19862.8626
# 22       NaN      NaN     NaN     NaN      NaN             NaN
#
#     Nat Inc pAdult.1  Nat Wealth pAdult  Wealth-Inc Ratio
# 0         14144.7280         10356.1138          0.890886
# 1         16917.9534         18031.7409          1.309158
# 2         19003.0928         26445.7982          1.728444
# 3         29693.3463         40917.3153          1.685792
# 4         33781.7149         45517.7047          1.653690
# 5         36536.1670         52778.4288          1.779734
# 6         47758.5816         78389.0930          2.000548
# 7         52796.3483         91283.0043          2.101777
# 8         54191.4141         96386.6649          2.161286
# 9         59348.9636        106050.3398          2.183203
# 10        66240.4755        117965.7398          2.166185
# 11        63507.3710        107691.5633          2.157302
# 12        54733.4669         87639.7818          2.050335
# 13        55849.9640         89138.2227          2.031685
# 14        57803.0436         93359.3469          2.069029
# 15        52830.0008         85430.0938          2.108222
# 16        50508.8658         80745.5391          2.104516
# 17        43721.5862         64587.8987          2.059356
# 18        38539.1077         53606.8191          2.002292
# 19        35045.0157         49425.7800          1.997562
# 20        31545.1525         45095.0435          2.000524
# 21        28578.5177         40194.3598          2.023593
# 22               NaN                NaN               NaN

# %%
# df_cpi_guinea = df_cpi_guinea[df_cpi_guinea['Variable'].astype(str).str.isdecimal()]
df_cpi_guinea.isnull().sum()
# Out:
# Variable             1
# p90p100              1
# p50p90               1
# p0p50                1
# p99p100              1
# Nat Inc pAdult       1
# Nat Inc pAdult.1     1
# Nat Wealth pAdult    1
# Wealth-Inc Ratio     1
# dtype: int64

# %%
df_cpi_guinea = df_cpi_guinea.dropna()
df_cpi_guinea
# Out:
#     Variable  p90p100  p50p90   p0p50  p99p100  Nat Inc pAdult  \
# 0     1998.0   0.5116  0.3690  0.1187   0.1647      11624.5063
# 1     1999.0   0.5136  0.3678  0.1179   0.1668      13773.5394
# 2     2000.0   0.5156  0.3665  0.1190   0.1689      15300.3521
# 3     2001.0   0.5124  0.3686  0.1198   0.1672      24271.8596
# 4     2002.0   0.5096  0.3706  0.1207   0.1643      27524.9361
# 5     2003.0   0.5065  0.3728  0.1208   0.1606      29655.2327
# 6     2004.0   0.5055  0.3737  0.1147   0.1595      39183.8124
# 7     2005.0   0.5206  0.3647  0.1151   0.1799      43431.3384
# 8     2006.0   0.5191  0.3658  0.1155   0.1781      44596.8982
# 9     2007.0   0.5176  0.3670  0.1157   0.1763      48575.5827
# 10    2008.0   0.5168  0.3676  0.1163   0.1753      54457.8246
# 11    2009.0   0.5144  0.3693  0.1169   0.1728      49919.5490
# 12    2010.0   0.5121  0.3710  0.1175   0.1703      42744.1209
# 13    2011.0   0.5098  0.3728  0.1182   0.1678      43874.0274
# 14    2012.0   0.5072  0.3746  0.1174   0.1650      45122.3024
# 15    2013.0   0.5089  0.3737  0.1166   0.1668      40522.3497
# 16    2014.0   0.5106  0.3727  0.1161   0.1686      38367.7465
# 17    2015.0   0.5120  0.3719  0.1156   0.1703      31363.1582
# 18    2016.0   0.5134  0.3710  0.1150   0.1722      26772.7323
# 19    2017.0   0.5149  0.3701  0.1145   0.1740      24743.0508
# 20    2018.0   0.5164  0.3691  0.1145   0.1759      22541.6219
# 21    2019.0   0.5164  0.3692  0.1145   0.1759      19862.8626
#
#     Nat Inc pAdult.1  Nat Wealth pAdult  Wealth-Inc Ratio
# 0         14144.7280         10356.1138          0.890886
# 1         16917.9534         18031.7409          1.309158
# 2         19003.0928         26445.7982          1.728444
# 3         29693.3463         40917.3153          1.685792
# 4         33781.7149         45517.7047          1.653690
# 5         36536.1670         52778.4288          1.779734
# 6         47758.5816         78389.0930          2.000548
# 7         52796.3483         91283.0043          2.101777
# 8         54191.4141         96386.6649          2.161286
# 9         59348.9636        106050.3398          2.183203
# 10        66240.4755        117965.7398          2.166185
# 11        63507.3710        107691.5633          2.157302
# 12        54733.4669         87639.7818          2.050335
# 13        55849.9640         89138.2227          2.031685
# 14        57803.0436         93359.3469          2.069029
# 15        52830.0008         85430.0938          2.108222
# 16        50508.8658         80745.5391          2.104516
# 17        43721.5862         64587.8987          2.059356
# 18        38539.1077         53606.8191          2.002292
# 19        35045.0157         49425.7800          1.997562
# 20        31545.1525         45095.0435          2.000524
# 21        28578.5177         40194.3598          2.023593

# %%
df_cpi_guinea.columns
# Out:
# Index(['Variable', 'p90p100', 'p50p90', 'p0p50', 'p99p100', 'Nat Inc pAdult',
#        'Nat Inc pAdult.1', 'Nat Wealth pAdult', 'Wealth-Inc Ratio'],
#       dtype='object')

# %%
# Create a graph describing Guinea.
df_cpi_guinea_plot1 = df_cpi_guinea.drop(['Variable', 'p99p100', 'Nat Inc pAdult', 'Nat Inc pAdult.1', 'Nat Wealth pAdult'], axis=1)
df_cpi_guinea_plot1_wo_WI_ratio = df_cpi_guinea.drop(['Variable', 'p99p100', 'Nat Inc pAdult', 'Nat Inc pAdult.1', 'Nat Wealth pAdult','Wealth-Inc Ratio'], axis=1)
ax_guinea1 = df_cpi_guinea_plot1_wo_WI_ratio.plot.bar(title='Trends in the share of wealth in Guinea',grid=True,stacked=True)
ax_guinea1.set_xlabel("Year")
ax_guinea1.set_ylabel("Out of 1.0")
df_cpi_guinea_plot1.plot(y='Wealth-Inc Ratio', kind="line")
# Out:
# <AxesSubplot:>

# %%
# df_cpi_guinea_plot2 = df_cpi_guinea.drop(['Variable', 'p99p100', 'Wealth-Inc Ratio', 'Nat Inc pAdult.1', 'Nat Wealth pAdult'], axis=1)
df_cpi_guinea_plot2_wo_WI_ratio = df_cpi_guinea.drop(['Variable', 'p99p100', 'Wealth-Inc Ratio', 'Nat Inc pAdult.1', 'Nat Wealth pAdult','Wealth-Inc Ratio'], axis=1)
ax_guinea2 = df_cpi_guinea_plot2_wo_WI_ratio.plot.bar(title='Trends in the share of wealth in oooooo',grid=True,stacked=True)
ax_guinea2.set_xlabel("Year")
ax_guinea2.set_ylabel("Out of 1.0")
df_cpi_guinea_plot2.plot(y='Nat Inc pAdult' , kind="line")

# %% [markdown]
# ## According to the graph above, the national wealth income ratio has fluctuated greatly, even though the percentage of wealth share has hardly changed in the case of Guinea.
#
# ### The national wealth income ratio, also known as ICOR, is generally considered to be a measure of the inefficiency with which capital is used.
#
# ### In other words, even though the share of wealth has not changed, there has been a very large movement in indicators of inefficient use of capital in general.
#
# ## Compared with my research question, it seems that there is no correlation between the share of wealth and the efficiency of capital use in general.

# %%
df_cpi_nigeria= pd.read_csv('../data/raw/00cpi_xxxx/cpi_nigeria.csv',header=1)
missing_columns_nigeria = ['CPI', '10/50 Ratio', 'Pop', 'Unnamed: 12']
df_cpi_nigeria.drop(missing_columns_nigeria, axis=1, inplace=True)
df_cpi_nigeria = df_cpi_nigeria.dropna()
df_cpi_nigeria
# Out:
#     Variable  p90p100  p50p90   p0p50  p99p100  Nat Inc pAdult  \
# 0     1998.0   0.4649  0.4091  0.1260   0.1252       5817.0503
# 1     1999.0   0.4644  0.4078  0.1277   0.1274       5501.6423
# 2     2000.0   0.4639  0.4066  0.1295   0.1295       5603.2142
# 3     2001.0   0.4634  0.4053  0.1313   0.1316       5822.4609
# 4     2002.0   0.4629  0.4040  0.1330   0.1337       6611.4841
# 5     2003.0   0.4624  0.4028  0.1348   0.1358       6886.6742
# 6     2004.0   0.4683  0.3990  0.1327   0.1389       7212.3996
# 7     2005.0   0.4742  0.3952  0.1306   0.1419       7573.7472
# 8     2006.0   0.4800  0.3914  0.1286   0.1449       7864.3024
# 9     2007.0   0.4859  0.3876  0.1265   0.1479       7884.6984
# 10    2008.0   0.4918  0.3838  0.1244   0.1509       8214.9029
# 11    2009.0   0.4976  0.3801  0.1223   0.1539       8601.2031
# 12    2010.0   0.4898  0.3842  0.1259   0.1497       9043.0206
# 13    2011.0   0.4820  0.3884  0.1295   0.1455       9218.5720
# 14    2012.0   0.4742  0.3926  0.1332   0.1413       9384.7331
# 15    2013.0   0.4664  0.3968  0.1368   0.1371       9803.7324
# 16    2014.0   0.4586  0.4010  0.1404   0.1328      10331.5040
# 17    2015.0   0.4508  0.4052  0.1440   0.1286      10411.8236
# 18    2016.0   0.4429  0.4094  0.1477   0.1244      10127.2106
# 19    2017.0   0.4351  0.4136  0.1513   0.1201       9883.8280
# 20    2018.0   0.4272  0.4178  0.1550   0.1159       9798.7850
# 21    2019.0   0.4272  0.4178  0.1550   0.1159       9844.0407
#
#     Nat Inc pAdult.1  Nat Wealth pAdult  Wealth-Inc Ratio
# 0          6090.7987         22702.6587          3.902778
# 1          5956.1119         20982.3088          3.813827
# 2          6079.0929         21144.1549          3.773576
# 3          6274.5068         22685.6353          3.896228
# 4          7047.3080         26738.0065          4.044177
# 5          7364.7274         28149.9669          4.087600
# 6          7831.2405         30171.9474          4.183344
# 7          8111.7107         32682.7914          4.315274
# 8          8386.7653         34976.5311          4.447506
# 9          8709.0440         35920.7898          4.555760
# 10         9055.5278         38003.3634          4.626149
# 11         9527.6320         40286.1785          4.683784
# 12        10021.8562         42304.3692          4.678123
# 13        10288.0372         43304.7908          4.697560
# 14        10452.0163         44278.3003          4.718121
# 15        10865.1827         46276.6814          4.720313
# 16        11251.7267         48741.7752          4.717781
# 17        11245.1641         49138.4710          4.719488
# 18        10780.5057         47900.5273          4.729883
# 19        10580.9810         46870.9092          4.742182
# 20        10493.4946         46601.4367          4.755838
# 21        10431.1536         46966.5726          4.771066

# %%
# Create a graph describing Guinea.
df_cpi_nigeria_plot1 = df_cpi_nigeria.drop(['Variable', 'p99p100', 'Nat Inc pAdult', 'Nat Inc pAdult.1', 'Nat Wealth pAdult'], axis=1)
df_cpi_nigeria_plot1_wo_WI_ratio = df_cpi_nigeria.drop(['Variable', 'p99p100', 'Nat Inc pAdult', 'Nat Inc pAdult.1', 'Nat Wealth pAdult','Wealth-Inc Ratio'], axis=1)
ax_nigeria1 = df_cpi_nigeria_plot1_wo_WI_ratio.plot.bar(title='Trends in the share of wealth in Nigeria',grid=True,stacked=True)
ax_nigeria1.set_xlabel("Year")
ax_nigeria1.set_ylabel("Out of 1.0")
df_cpi_nigeria_plot1.plot(y='Wealth-Inc Ratio', kind="line")
# Out:
# <AxesSubplot:>

# %%
df_cpi_congo= pd.read_csv('../data/raw/00cpi_xxxx/cpi_congo.csv',header=1)
missing_columns_congo = ['CPI', '10/50 Ratio', 'Pop', 'Unnamed: 12']
df_cpi_congo.drop(missing_columns_congo, axis=1, inplace=True)
df_cpi_congo = df_cpi_congo.dropna()
df_cpi_congo
# Out:
#     Variable  p90p100  p50p90   p0p50  p99p100  Nat Inc pAdult  \
# 0     1998.0   0.5453  0.3508  0.1039   0.1858       5537.0836
# 1     1999.0   0.5453  0.3508  0.1039   0.1858       4623.3817
# 2     2000.0   0.5453  0.3508  0.1039   0.1858       4651.5252
# 3     2001.0   0.5453  0.3508  0.1039   0.1858       4775.0481
# 4     2002.0   0.5453  0.3508  0.1039   0.1858       4521.6139
# 5     2003.0   0.5453  0.3508  0.1039   0.1858       5221.8319
# 6     2004.0   0.5453  0.3508  0.1039   0.1858       4936.2058
# 7     2005.0   0.5453  0.3508  0.1031   0.1858       4756.8181
# 8     2006.0   0.5477  0.3493  0.1023   0.1890       5238.1846
# 9     2007.0   0.5500  0.3477  0.1015   0.1923       4997.4003
# 10    2008.0   0.5523  0.3462  0.1007   0.1955       5400.2325
# 11    2009.0   0.5546  0.3446  0.0999   0.1988       6231.0965
# 12    2010.0   0.5570  0.3431  0.0992   0.2020       6743.6602
# 13    2011.0   0.5593  0.3416  0.0992   0.2052       6412.7672
# 14    2012.0   0.5593  0.3416  0.0992   0.2052       7339.6027
# 15    2013.0   0.5593  0.3416  0.0992   0.2052       7367.0441
# 16    2014.0   0.5593  0.3416  0.0992   0.2052       8082.1014
# 17    2015.0   0.5593  0.3416  0.0992   0.2052       7490.3308
# 18    2016.0   0.5593  0.3416  0.0992   0.2052       6227.0195
# 19    2017.0   0.5593  0.3416  0.0992   0.2052       5805.1038
# 20    2018.0   0.5593  0.3416  0.0992   0.2052       5295.8452
# 21    2019.0   0.5593  0.3416  0.0992   0.2052       4971.8482
#
#     Nat Inc pAdult.1  Nat Wealth pAdult  Wealth-Inc Ratio
# 0          7890.9680         20779.1843          3.752731
# 1          7419.2887         17635.2056          3.814352
# 2          7706.5109         19882.5542          4.274416
# 3          7746.5766         19971.2592          4.182421
# 4          7845.6356         18982.1800          4.198099
# 5          7656.9612         22676.2140          4.342578
# 6          7663.9585         21745.3699          4.405280
# 7          7980.6179         21415.3146          4.502025
# 8          8309.0300         24214.9850          4.622782
# 9          7475.1340         23364.7736          4.675385
# 10         7657.5034         25519.1287          4.725562
# 11         8249.5510         28930.7345          4.642961
# 12         8770.0938         31903.9705          4.730958
# 13         8744.7054         30463.6473          4.750468
# 14         9396.2048         34922.5791          4.758102
# 15         9125.8125         34670.3015          4.706135
# 16         9456.8600         37372.8850          4.624155
# 17         8940.8484         31763.1318          4.240551
# 18         7825.3926         26509.7474          4.257213
# 19         7263.7941         24596.8785          4.237113
# 20         6625.3378         22398.5666          4.229460
# 21         6211.6904         21193.2948          4.262660

# %%
# Create a graph describing Guinea.
df_cpi_congo_plot1 = df_cpi_congo.drop(['Variable', 'p99p100', 'Nat Inc pAdult', 'Nat Inc pAdult.1', 'Nat Wealth pAdult'], axis=1)
df_cpi_congo_plot1_wo_WI_ratio = df_cpi_congo.drop(['Variable', 'p99p100', 'Nat Inc pAdult', 'Nat Inc pAdult.1', 'Nat Wealth pAdult','Wealth-Inc Ratio'], axis=1)
ax_congo1 = df_cpi_congo_plot1_wo_WI_ratio.plot.bar(title='Trends in the share of wealth in Congo',grid=True,stacked=True)
ax_congo1.set_xlabel("Year")
ax_congo1.set_ylabel("Out of 1.0")
df_cpi_congo_plot1.plot(y='Wealth-Inc Ratio', kind="line")
# Out:
# <AxesSubplot:>

# %%
df_cpi_mauritius= pd.read_csv('../data/raw/00cpi_xxxx/cpi_mauritius.csv',header=1)
missing_columns_mauritius = ['CPI', '10/50 Ratio', 'Pop', 'Unnamed: 12']
df_cpi_mauritius.drop(missing_columns_mauritius, axis=1, inplace=True)
df_cpi_mauritius = df_cpi_mauritius.dropna()
df_cpi_mauritius
# Out:
#     Variable  p90p100  p50p90   p0p50  p99p100  Nat Inc pAdult  \
# 0     1998.0   0.4578  0.3901  0.1520   0.1374      12783.4058
# 1     1999.0   0.4578  0.3901  0.1520   0.1374      13690.6223
# 2     2000.0   0.4578  0.3901  0.1520   0.1374      14002.9229
# 3     2001.0   0.4578  0.3901  0.1520   0.1374      14514.1506
# 4     2002.0   0.4578  0.3901  0.1520   0.1374      15420.4451
# 5     2003.0   0.4578  0.3901  0.1520   0.1374      16528.3231
# 6     2004.0   0.4578  0.3901  0.1520   0.1374      17623.7730
# 7     2005.0   0.4578  0.3901  0.1520   0.1374      18699.1575
# 8     2006.0   0.4578  0.3901  0.1520   0.1374      20726.5582
# 9     2007.0   0.4643  0.3857  0.1501   0.1429      22809.3805
# 10    2008.0   0.4707  0.3812  0.1481   0.1483      22844.7621
# 11    2009.0   0.4772  0.3767  0.1461   0.1538      21675.8293
# 12    2010.0   0.4836  0.3723  0.1441   0.1592      21160.6821
# 13    2011.0   0.4900  0.3678  0.1421   0.1647      21634.5830
# 14    2012.0   0.4965  0.3634  0.1402   0.1701      22863.2529
# 15    2013.0   0.4920  0.3663  0.1417   0.1679      24729.7058
# 16    2014.0   0.4875  0.3692  0.1433   0.1656      28479.8100
# 17    2015.0   0.4830  0.3721  0.1449   0.1634      26817.5298
# 18    2016.0   0.4785  0.3750  0.1465   0.1612      24214.6176
# 19    2017.0   0.4740  0.3779  0.1481   0.1589      25047.5091
# 20    2018.0   0.4740  0.3779  0.1481   0.1589      26602.6760
# 21    2019.0   0.4740  0.3779  0.1481   0.1589      21035.4949
#
#     Nat Inc pAdult.1  Nat Wealth pAdult  Wealth-Inc Ratio
# 0         13855.7675         51900.9383          4.060024
# 1         14101.1992         57756.4098          4.218684
# 2         14826.9775         61241.5769          4.373485
# 3         15197.6426         66289.7585          4.567250
# 4         15329.9491         83515.9722          5.415926
# 5         16352.6022        100961.2035          6.108375
# 6         17111.8549        116439.9752          6.606984
# 7         17256.2443        137877.6100          7.373466
# 8         17804.3692        165375.3690          7.978911
# 9         18402.8089        198724.8147          8.712418
# 10        18980.1055        211455.4890          9.256192
# 11        18975.0324        226299.5468         10.440180
# 12        18659.5700        215913.4322         10.203521
# 13        19292.9240        185208.2419          8.560749
# 14        19734.7987        165462.9516          7.237069
# 15        20167.4997        162905.3400          6.587436
# 16        20688.6505        174933.7158          6.142376
# 17        21190.0686        163605.2472          6.100683
# 18        21792.4279        146988.0027          6.070217
# 19        22415.3788        150349.0267          6.002553
# 20        23049.9580        157174.7778          5.908232
# 21        23534.1694        124748.1133          5.930363

# %%
# Create a graph describing Guinea.
df_cpi_mauritius_plot1 = df_cpi_mauritius.drop(['Variable', 'p99p100', 'Nat Inc pAdult', 'Nat Inc pAdult.1', 'Nat Wealth pAdult'], axis=1)
df_cpi_mauritius_plot1_wo_WI_ratio = df_cpi_mauritius.drop(['Variable', 'p99p100', 'Nat Inc pAdult', 'Nat Inc pAdult.1', 'Nat Wealth pAdult','Wealth-Inc Ratio'], axis=1)
ax_mauritius1 = df_cpi_mauritius_plot1_wo_WI_ratio.plot.bar(title='Trends in the share of wealth in Mauritius',grid=True,stacked=True)
ax_mauritius1.set_xlabel("Year")
ax_mauritius1.set_ylabel("Out of 1.0")
df_cpi_mauritius_plot1.plot(y='Wealth-Inc Ratio', kind="line")
# Out:
# <AxesSubplot:>
